# %% [markdown]
# Основы Pandas для начинающих
# https://stepik.org/lesson/746102/step/1?unit=747903

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Контрольная работа

# %% [markdown]
# ### Датафрейм с которым вы будете сегодня работать

# %%
data = [['Girev', 'Andrey', 'ВИП', 2815, 29, 58, 6358, 'Moscow', 'Xiaomi'],
       ['Bykin', 'Stas', 'Все за 300', 3634, 37, 78, 602, 'Kazan',
        'Samsung'],
       ['Ivanov', 'Alex', 'Всё за 800', 410, 47, 81, 3582, 'Moscow',
        'Huawei'],
       ['Andreev', 'Sergey', 'Всё за 500', 1981, 75, 98, 5442, 'Kazan',
        'Apple'],
       ['Girev', 'Stas', 'Всё за 800', 4969, 43, 61, 8510, 'Moscow',
        'Samsung'],
       ['Bykin', 'Andrey', 'Всё за 500', 4308, 49, 39, 2525, 'Moscow',
        'Xiaomi'],
       ['Kozlov', 'Igor', 'Всё за 800', 300, 60, 31, 8543, 'Yakutsk',
        'Samsung'],
       ['Girev', 'Alex', 'Промо', 4199, 47, 90, 3925, 'Kazan', 'Apple'],
       ['Petrov', 'Nikolay', 'ВИП', 4810, 72, 88, 7188, 'Moscow',
        'Apple'],
       ['Andreev', 'Sergey', 'Всё за 800', 4118, 52, 53, 419, 'Yakutsk',
        'Apple'],
       ['Smolov', 'Stas', 'Промо', 1991, 28, 67, 5016, 'Kazan', 'Xiaomi'],
       ['Girev', 'Igor', 'Корпоративный', 1430, 69, 19, 9520, 'Yakutsk',
        'Samsung'],
       ['Kozlov', 'Andrey', 'Корпоративный', 113, 71, 82, 2785, 'Kazan',
        'Apple'],
       ['Ivanov', 'Sergey', 'Промо', 3394, 39, 12, 2718, 'Yakutsk',
        'Xiaomi'],
       ['Smolov', 'Sergey', 'Всё за 250 (архив)', 3493, 32, 6, 8959,
        'Yakutsk', 'Huawei'],
       ['Kozlov', 'Stas', 'Всё за 800', 4565, 59, 82, 3168, 'Moscow',
        'Apple'],
       ['Vlasov', 'Andrey', 'Всё за 800', 3192, 29, 74, 2852, 'Yakutsk',
        'Xiaomi'],
       ['Smolov', 'Alex', 'Корпоративный', 3764, 71, 22, 2768, 'Moscow',
        'Huawei'],
       ['Vlasov', 'Sergey', 'Всё за 800', 3816, 28, 35, 5734,
        'Vladivostok', 'Apple'],
       ['Bykin', 'Alex', 'Промо', 817, 65, 34, 2131, 'Vladivostok',
        'Samsung'],
       ['Andreev', 'Nikolay', 'Всё за 500', 385, 49, 62, 1815, 'Kazan',
        'Xiaomi'],
       ['Bykin', 'Igor', 'Всё за 500', 2642, 38, 11, 3787, 'Moscow',
        'Xiaomi'],
       ['Girev', 'Sergey', 'Все за 300', 4230, 62, 68, 5512,
        'Vladivostok', 'Samsung'],
       ['Bykin', 'Sergey', 'Всё за 800', 4100, 48, 39, 227, 'Moscow',
        'Xiaomi'],
       ['Girev', 'Stas', 'Все за 300', 3371, 53, 24, 7946, 'Kazan',
        'Apple'],
       ['Smolov', 'Sergey', 'Корпоративный', 3577, 70, 71, 8847,
        'Yakutsk', 'Huawei'],
       ['Mezov', 'Nikolay', 'Всё за 250 (архив)', 2742, 28, 19, 7115,
        'Yakutsk', 'Huawei'],
       ['Smolov', 'Stas', 'Всё за 500', 2644, 41, 33, 8341, 'Moscow',
        'Xiaomi'],
       ['Vlasov', 'Andrey', 'Всё за 500', 4725, 26, 93, 9441,
        'Vladivostok', 'Xiaomi'],
       ['Ivanov', 'Nikolay', 'Всё за 500', 2785, 41, 5, 2901, 'Moscow',
        'Samsung']]

df = pd.DataFrame(data, columns = ['surname', 'name', 'tarif', 'balance', 'age', 'sms', 'voice', 'city', 'phone'])

# %%
df
# Out:
#     surname     name               tarif  balance  age  sms  voice  \
# 0     Girev   Andrey                 ВИП     2815   29   58   6358
# 1     Bykin     Stas          Все за 300     3634   37   78    602
# 2    Ivanov     Alex          Всё за 800      410   47   81   3582
# 3   Andreev   Sergey          Всё за 500     1981   75   98   5442
# 4     Girev     Stas          Всё за 800     4969   43   61   8510
# 5     Bykin   Andrey          Всё за 500     4308   49   39   2525
# 6    Kozlov     Igor          Всё за 800      300   60   31   8543
# 7     Girev     Alex               Промо     4199   47   90   3925
# 8    Petrov  Nikolay                 ВИП     4810   72   88   7188
# 9   Andreev   Sergey          Всё за 800     4118   52   53    419
# 10   Smolov     Stas               Промо     1991   28   67   5016
# 11    Girev     Igor       Корпоративный     1430   69   19   9520
# 12   Kozlov   Andrey       Корпоративный      113   71   82   2785
# ...

# %%
#surname    - Фамилия клиента 
#name       - Имя клиента
#tarif      - Тариф клиента
#balance	- Баланс клиента
#age	    - Возраст клиента
#sms	    - Количество отправленных СМС
#voice	    - Количество секунд разговора (звонки)
#city	    - Город клиента
#phone      - Марка телефона клиента

# %%
df.describe()
# Out:
#            balance        age        sms        voice
# count    30.000000  30.000000  30.000000    30.000000
# mean   2977.333333  48.600000  51.166667  4955.900000
# std    1451.525389  15.712064  29.124090  2919.038285
# min     113.000000  26.000000   5.000000   227.000000
# 25%    2153.750000  37.250000  25.750000  2772.250000
# 50%    3382.500000  47.500000  55.500000  4470.500000
# 75%    4113.500000  61.500000  77.000000  7756.500000
# max    4969.000000  75.000000  98.000000  9520.000000

# %%
df[['surname', 'name', 'tarif', 'city', 'phone']].describe()
# Out:
#        surname    name       tarif    city   phone
# count       30      30          30      30      30
# unique       9       6           7       4       4
# top      Girev  Sergey  Всё за 800  Moscow  Xiaomi
# freq         6       8           8      11      10

# %%
df.describe(include=np.object)
# Out:
#        surname    name       tarif    city   phone
# count       30      30          30      30      30
# unique       9       6           7       4       4
# top      Girev  Sergey  Всё за 800  Moscow  Xiaomi
# freq         6       8           8      11      10

# %% [markdown]
# ## Ответы на вопросы загрузите на степик

# %% [markdown]
# ### Вопрос 1: определите средний возраст клиента

# %%
df.age.mean()
# Out:
# 48.6

# %% [markdown]
# ### Вопрос 2: на каком тарифе средний возраст клиента наименьший

# %%
df.groupby('tarif').age.mean().idxmin()
# Out:
# 'Всё за 250 (архив)'

# %% [markdown]
# ### Вопрос 3: с какого города больше всего клиентов?

# %%
df.city.value_counts().idxmax()
# Out:
# 'Moscow'

# %% [markdown]
# ### Вопрос 4: на каком тарифе отправили больше всего СМС?

# %%
df.groupby('tarif').sms.sum().idxmax()
# Out:
# 'Всё за 800'

# %% [markdown]
# ### Вопрос 5: определите самую популярную марку смартфона у пользователей до 40 (включительно)

# %%
df.query("age <= 40").groupby('phone').phone.count().idxmax()
# балбес: value_counts, конено же
# Out:
# 'Xiaomi'

# %% [markdown]
# ### Вопрос 6: определите самую популярную марку смартфона у пользователей старше 40

# %%
df.query("age > 40").phone.value_counts().idxmax()
# Out:
# 'Apple'

# %% [markdown]
# ### Вопрос 7: В каком городе клиенты меньше всего отправляют СМС

# %%
df.groupby('city').sms.sum().idxmin()
# Out:
# 'Vladivostok'

# %% [markdown]
# ### Вопрос 8: В каком городе клиенты больше всего говорят по телефону?

# %%
df.groupby('city').voice.sum().idxmax()
# Out:
# 'Moscow'

# %% [markdown]
# ### Вопрос 9: Сколько заработала фирма на СМС сообщениях? Стоимость одного сообщения 3 рубля.

# %%
3 * df.sms.sum()
# Out:
# 4605

# %% [markdown]
# ### Вопрос 10: Сколько заработала фирма на СМС сообщениях? Тарифная сетка:
# #### ВИП                   - 1 рубль за СМС
# ####  Все за 300            - 2 рубля за СМС
# ####  Всё за 500            - 3 рубля за СМС
# ####  Всё за 800            - 4 рубля за СМС
# ####  Промо                 - 7 рублей за СМС
# ####  Корпоративный         - 0 рублей за СМС
# ####  Всё за 250 (архив)    - 5 рублей за СМС

# %%
df2 = df.groupby('tarif').sms.sum() 
df2
# Out:
# tarif
# ВИП                   146
# Все за 300            170
# Всё за 250 (архив)     25
# Всё за 500            341
# Всё за 800            456
# Корпоративный         194
# Промо                 203
# Name: sms, dtype: int64

# %%
pd.Series([1, 2, 5, 3, 4, 0, 7], index=df2.index)
# Out:
# tarif
# ВИП                   1
# Все за 300            2
# Всё за 250 (архив)    5
# Всё за 500            3
# Всё за 800            4
# Корпоративный         0
# Промо                 7
# dtype: int64

# %%
(df2 * pd.Series([1, 2, 5, 3, 4, 0, 7], index=df2.index)).sum()
# Out:
# 4879

# %% [markdown]
# ### Вопрос 11: Определите процент клиентов, у которых баланс выше 4000

# %%
df.query("balance > 4000").balance.count() / df.shape[0] * 100
# Out:
# 30.0

# %% [markdown]
# ### Вопрос 12: Определите процент клиентов, у которых баланс выше 2000 и тариф 'Всё за 500'

# %%
df.query("balance > 2000 & tarif == 'Всё за 500'").balance.count() / df.shape[0] * 100
# Out:
# 16.666666666666664

# %% [markdown]
# ### Вопрос 13: Сколько клиентов из Москвы, у которых баланс выше 1500 и марка телефона 'Apple'?

# %%
df.query("balance > 1500 & phone == 'Apple' & city == 'Moscow'").shape[0]
# Out:
# 2

# %% [markdown]
# ### Вопрос 14: Самое распространённое имя среди наших клиентов?

# %%
df.name.value_counts().idxmax()
# Out:
# 'Sergey'

# %% [markdown]
# ### Вопрос 15: Определите процент клиентов у которых телефон Apple и они из Владивостока

# %%
df.query("phone == 'Apple' & city == 'Vladivostok'").shape[0] / df.shape[0] * 100
# Out:
# 3.3333333333333335

# %% [markdown]
# ________________

# %% [markdown]
# ## ЧАСТЬ 2

# %% [markdown]
# **№1**
# Объедините столбцы surname и name в столбец с именем client_name

# %%
df.head()
# Out:
#    surname    name       tarif  balance  age  sms  voice    city    phone
# 0    Girev  Andrey         ВИП     2815   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300     3634   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800      410   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500     1981   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800     4969   43   61   8510  Moscow  Samsung

# %%
df['client_name'] = df.surname + ' ' + df.name

# %%
df.head()
# Out:
#    surname    name       tarif  balance  age  sms  voice    city    phone  \
# 0    Girev  Andrey         ВИП     2815   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300     3634   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800      410   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500     1981   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800     4969   43   61   8510  Moscow  Samsung
#
#       client_name
# 0    Girev Andrey
# 1      Bykin Stas
# 2     Ivanov Alex
# 3  Andreev Sergey
# 4      Girev Stas

# %% [markdown]
# **№2**
# Поступила задача разбить клиентов на группы:
# * до 25 лет (включительно) - A (англ. буква)
# * с 26 до 40 лет (включительно) - B (англ. буква)
# * старше 40 лет - C (англ. буква)
#
# Запишите название группы в столбец group

# %%
df.head()
# Out:
#    surname    name       tarif  balance  age  sms  voice    city    phone
# 0    Girev  Andrey         ВИП     2815   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300     3634   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800      410   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500     1981   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800     4969   43   61   8510  Moscow  Samsung

# %%
df['group'] = pd.cut(df.age, bins=[0, 25, 40, 76], labels=['A', 'B', 'C'])
df.head()
# Out:
#    surname    name       tarif  balance  age  sms  voice    city    phone  \
# 0    Girev  Andrey         ВИП     2815   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300     3634   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800      410   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500     1981   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800     4969   43   61   8510  Moscow  Samsung
#
#   group
# 0     B
# 1     B
# 2     C
# 3     C
# 4     C

# %% [markdown]
# **№3**
# Пришла информация, что на сервере в Москве возник сбой и баланс за отправленные смс не списался (у пользователей из Москвы). Спишите с каждого пользователя из Москвы деньги за смс. Количество отправленных смс за которые не списали деньги в столбце sms. Стоимость 1 смс - 3 рубля. (обновите колонку balance)

# %%
df.head()
# Out:
#    surname    name       tarif  balance  age  sms  voice    city    phone
# 0    Girev  Andrey         ВИП     2815   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300     3634   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800      410   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500     1981   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800     4969   43   61   8510  Moscow  Samsung

# %%
df['balance'] = df['balance'].sub(3 * df[df.city == 'Moscow'].sms, fill_value=0).astype(int)
df.head()
# Out:
#    surname    name       tarif  balance  age  sms  voice    city    phone
# 0    Girev  Andrey         ВИП     2641   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300     3634   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800      167   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500     1981   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800     4786   43   61   8510  Moscow  Samsung

# %%
data = [['Girev', 'Andrey', 'ВИП', 2815, 29, 58, 6358, 'Moscow', 'Xiaomi'],
       ['Bykin', 'Stas', 'Все за 300', 3634, 37, 78, 602, 'Kazan',
        'Samsung'],
       ['Ivanov', 'Alex', 'Всё за 800', 410, 47, 81, 3582, 'Moscow',
        'Huawei'],
       ['Andreev', 'Sergey', 'Всё за 500', 1981, 75, 98, 5442, 'Kazan',
        'Apple'],
       ['Girev', 'Stas', 'Всё за 800', 4969, 43, 61, 8510, 'Moscow',
        'Samsung'],
       ['Bykin', 'Andrey', 'Всё за 500', 4308, 49, 39, 2525, 'Moscow',
        'Xiaomi'],
       ['Kozlov', 'Igor', 'Всё за 800', 300, 60, 31, 8543, 'Yakutsk',
        'Samsung'],
       ['Girev', 'Alex', 'Промо', 4199, 47, 90, 3925, 'Kazan', 'Apple'],
       ['Petrov', 'Nikolay', 'ВИП', 4810, 72, 88, 7188, 'Moscow',
        'Apple'],
       ['Andreev', 'Sergey', 'Всё за 800', 4118, 52, 53, 419, 'Yakutsk',
        'Apple'],
       ['Smolov', 'Stas', 'Промо', 1991, 28, 67, 5016, 'Kazan', 'Xiaomi'],
       ['Girev', 'Igor', 'Корпоративный', 1430, 69, 19, 9520, 'Yakutsk',
        'Samsung'],
       ['Kozlov', 'Andrey', 'Корпоративный', 113, 71, 82, 2785, 'Kazan',
        'Apple'],
       ['Ivanov', 'Sergey', 'Промо', 3394, 39, 12, 2718, 'Yakutsk',
        'Xiaomi'],
       ['Smolov', 'Sergey', 'Всё за 250 (архив)', 3493, 32, 6, 8959,
        'Yakutsk', 'Huawei'],
       ['Kozlov', 'Stas', 'Всё за 800', 4565, 59, 82, 3168, 'Moscow',
        'Apple'],
       ['Vlasov', 'Andrey', 'Всё за 800', 3192, 29, 74, 2852, 'Yakutsk',
        'Xiaomi'],
       ['Smolov', 'Alex', 'Корпоративный', 3764, 71, 22, 2768, 'Moscow',
        'Huawei'],
       ['Vlasov', 'Sergey', 'Всё за 800', 3816, 28, 35, 5734,
        'Vladivostok', 'Apple'],
       ['Bykin', 'Alex', 'Промо', 817, 65, 34, 2131, 'Vladivostok',
        'Samsung'],
       ['Andreev', 'Nikolay', 'Всё за 500', 385, 49, 62, 1815, 'Kazan',
        'Xiaomi'],
       ['Bykin', 'Igor', 'Всё за 500', 2642, 38, 11, 3787, 'Moscow',
        'Xiaomi'],
       ['Girev', 'Sergey', 'Все за 300', 4230, 62, 68, 5512,
        'Vladivostok', 'Samsung'],
       ['Bykin', 'Sergey', 'Всё за 800', 4100, 48, 39, 227, 'Moscow',
        'Xiaomi'],
       ['Girev', 'Stas', 'Все за 300', 3371, 53, 24, 7946, 'Kazan',
        'Apple'],
       ['Smolov', 'Sergey', 'Корпоративный', 3577, 70, 71, 8847,
        'Yakutsk', 'Huawei'],
       ['Mezov', 'Nikolay', 'Всё за 250 (архив)', 2742, 28, 19, 7115,
        'Yakutsk', 'Huawei'],
       ['Smolov', 'Stas', 'Всё за 500', 2644, 41, 33, 8341, 'Moscow',
        'Xiaomi'],
       ['Vlasov', 'Andrey', 'Всё за 500', 4725, 26, 93, 9441,
        'Vladivostok', 'Xiaomi'],
       ['Ivanov', 'Nikolay', 'Всё за 500', 2785, 41, 5, 2901, 'Moscow',
        'Samsung']]

df = pd.DataFrame(data, columns = ['surname', 'name', 'tarif', 'balance', 'age', 'sms', 'voice', 'city', 'phone'])
df.head()
# Out:
#    surname    name       tarif  balance  age  sms  voice    city    phone
# 0    Girev  Andrey         ВИП     2815   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300     3634   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800      410   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500     1981   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800     4969   43   61   8510  Moscow  Samsung

# %%
df.balance[df.city == 'Moscow'] -= df.sms*3
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    surname    name       tarif  balance  age  sms  voice    city    phone
# 0    Girev  Andrey         ВИП     2641   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300     3634   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800      167   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500     1981   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800     4786   43   61   8510  Moscow  Samsung

# %%
df[df.city == 'Moscow'].balance -= df.sms*3
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df.balance = df.balance - df[df.city == 'Moscow'].sms*3
df.head()
# Out:
#    surname    name       tarif  balance  age  sms  voice    city    phone
# 0    Girev  Andrey         ВИП   2641.0   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300      NaN   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800    167.0   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500      NaN   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800   4786.0   43   61   8510  Moscow  Samsung

# %% [markdown]
# **№4**
# Ваш коллега Юра отправил вам результаты обработки данных в файле .npz, но торопился и не успел написать под какими ключами сохранил массивы в файл. Скачайте файл, определите название ключа под которым сохранён первый массив в файле.

# %%
arr = np.load('data.npz')

# %%
arr.files
# Out:
# ['mykey1', 'mykey2']

# %%
arr['mykey1']
# Out:
# array([1, 2, 3])

# %%
list(arr.keys())
# Out:
# ['mykey1', 'mykey2']

# %% [markdown]
# **№5**
# На совещании было принято решение детальнее проработать вопрос списания денежных средств. Теперь, спишите деньги (у пользователей из Москвы за смс) с учетом тарифной сетки:
# ВИП - 1 рубль за СМС
# Все за 300 - 2 рубля за СМС
# Всё за 500 - 3 рубля за СМС
# Всё за 800 - 4 рубля за СМС
# Промо - 7 рублей за СМС
# Корпоративный - 0 рублей за СМС
# Всё за 250 (архив) - 5 рублей за СМС

# %%
df.head()
# Out:
#    surname    name       tarif  balance  age  sms  voice    city    phone
# 0    Girev  Andrey         ВИП     2815   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300     3634   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800      410   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500     1981   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800     4969   43   61   8510  Moscow  Samsung

# %%
dct_sms_cost = pd.Series({
        'ВИП': 1,
        'Все за 300': 2,
        'Всё за 500': 3,
        'Всё за 800': 4,
        'Промо': 7,
        'Корпоративный': 0,
        'Всё за 250 (архив)': 5}, name='price').to_frame()
dct_sms_cost
# Out:
#                     price
# ВИП                     1
# Все за 300              2
# Всё за 500              3
# Всё за 800              4
# Промо                   7
# Корпоративный           0
# Всё за 250 (архив)      5

# %%
pd.merge(df, dct_sms_cost, left_on='tarif', right_index=True)
# Out:
#     surname     name               tarif  balance  age  sms  voice  \
# 0     Girev   Andrey                 ВИП     2815   29   58   6358
# 8    Petrov  Nikolay                 ВИП     4810   72   88   7188
# 1     Bykin     Stas          Все за 300     3634   37   78    602
# 22    Girev   Sergey          Все за 300     4230   62   68   5512
# 24    Girev     Stas          Все за 300     3371   53   24   7946
# 2    Ivanov     Alex          Всё за 800      410   47   81   3582
# 4     Girev     Stas          Всё за 800     4969   43   61   8510
# 6    Kozlov     Igor          Всё за 800      300   60   31   8543
# 9   Andreev   Sergey          Всё за 800     4118   52   53    419
# 15   Kozlov     Stas          Всё за 800     4565   59   82   3168
# 16   Vlasov   Andrey          Всё за 800     3192   29   74   2852
# 18   Vlasov   Sergey          Всё за 800     3816   28   35   5734
# 23    Bykin   Sergey          Всё за 800     4100   48   39    227
# ...

# %%
df.loc[df.city == 'Moscow', 'balance'] \
            = df.balance \
            - df.sms * pd.merge(
                    df
                    , dct_sms_cost
                    , left_on='tarif'
                    , right_index=True)\
                .price
df
# Out:
#     surname     name               tarif  balance  age  sms  voice  \
# 0     Girev   Andrey                 ВИП     2757   29   58   6358
# 1     Bykin     Stas          Все за 300     3634   37   78    602
# 2    Ivanov     Alex          Всё за 800       86   47   81   3582
# 3   Andreev   Sergey          Всё за 500     1981   75   98   5442
# 4     Girev     Stas          Всё за 800     4725   43   61   8510
# 5     Bykin   Andrey          Всё за 500     4191   49   39   2525
# 6    Kozlov     Igor          Всё за 800      300   60   31   8543
# 7     Girev     Alex               Промо     4199   47   90   3925
# 8    Petrov  Nikolay                 ВИП     4722   72   88   7188
# 9   Andreev   Sergey          Всё за 800     4118   52   53    419
# 10   Smolov     Stas               Промо     1991   28   67   5016
# 11    Girev     Igor       Корпоративный     1430   69   19   9520
# 12   Kozlov   Andrey       Корпоративный      113   71   82   2785
# ...

# %% [markdown]
# **№6**
# Пользователь Girev Sergey написал заявление о том, что переехал из города Vladivostok в Kazan. Внесите изменения в датафрейм

# %%
df.loc[(df.name == 'Sergey') & (df.surname == 'Girev'), 'city'] = 'Kazan'
df[(df.name == 'Sergey') & (df.surname == 'Girev')]
# Out:
#    surname    name       tarif  balance  age  sms  voice   city    phone
# 22   Girev  Sergey  Все за 300     4230   62   68   5512  Kazan  Samsung

# %%
df.city[(df.name == 'Sergey') & (df.surname == 'Girev')] = 'Kazan'
df[(df.name == 'Sergey') & (df.surname == 'Girev')]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    surname    name       tarif  balance  age  sms  voice   city    phone
# 22   Girev  Sergey  Все за 300     4230   62   68   5512  Kazan  Samsung

# %% [markdown]
# **№7**
# Измените название колонки balance на client_balance

# %%
df.head()
# Out:
#    surname    name       tarif  balance  age  sms  voice    city    phone
# 0    Girev  Andrey         ВИП     2815   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300     3634   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800      410   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500     1981   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800     4969   43   61   8510  Moscow  Samsung

# %%
df = df.rename(columns={'balance': 'client_balance'})
df.head()
# Out:
#    surname    name       tarif  client_balance  age  sms  voice    city  \
# 0    Girev  Andrey         ВИП            2815   29   58   6358  Moscow
# 1    Bykin    Stas  Все за 300            3634   37   78    602   Kazan
# 2   Ivanov    Alex  Всё за 800             410   47   81   3582  Moscow
# 3  Andreev  Sergey  Всё за 500            1981   75   98   5442   Kazan
# 4    Girev    Stas  Всё за 800            4969   43   61   8510  Moscow
#
#      phone
# 0   Xiaomi
# 1  Samsung
# 2   Huawei
# 3    Apple
# 4  Samsung

# %% [markdown]
# **№8**
# Напишите название функции, которая выводит индекс минимального значения

# %%
df.sms.argmin()
# Out:
# 29

# %%
df_reindexed = df.set_index('surname').sort_index()
df_reindexed.head()
# Out:
#             name       tarif  balance  age  sms  voice     city    phone
# surname
# Andreev   Sergey  Всё за 500     1981   75   98   5442    Kazan    Apple
# Andreev   Sergey  Всё за 800     4118   52   53    419  Yakutsk    Apple
# Andreev  Nikolay  Всё за 500      385   49   62   1815    Kazan   Xiaomi
# Bykin       Stas  Все за 300     3634   37   78    602    Kazan  Samsung
# Bykin     Andrey  Всё за 500     4308   49   39   2525   Moscow   Xiaomi

# %%
df_reindexed.sms.idxmin()
# Out:
# 'Ivanov'

# %%
df_reindexed.iloc[14]
# Out:
# name          Nikolay
# tarif      Всё за 500
# balance          2785
# age                41
# sms                 5
# voice            2901
# city           Moscow
# phone         Samsung
# Name: Ivanov, dtype: object

# %% [markdown]
# **№9**
# Пересчитайте баланс пользователей в доллары по курсу 1 доллар = 60 рублей. Результат запишите в колонку balance_usd (ответ округлите до двух знаков после запятой)

# %%
df.head()
# Out:
#    surname    name       tarif  balance  age  sms  voice    city    phone
# 0    Girev  Andrey         ВИП     2815   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300     3634   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800      410   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500     1981   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800     4969   43   61   8510  Moscow  Samsung

# %%
df['balance_usd'] = (df.balance / 60).round(2)
df.head()
# Out:
#    surname    name       tarif  balance  age  sms  voice    city    phone  \
# 0    Girev  Andrey         ВИП     2815   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300     3634   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800      410   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500     1981   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800     4969   43   61   8510  Moscow  Samsung
#
#    balance_usd
# 0        46.92
# 1        60.57
# 2         6.83
# 3        33.02
# 4        82.82

# %% [markdown]
# **№10**
# Высшее руководство компании в ячейке с балансом (в долларах) хотят видеть знак доллара $. Вам как самому ответственному и подготовленному специалисту доверили довести дело до конца! Добавьте, пожалуйста, знак доллара)

# %%
df.head()
# Out:
#    surname    name       tarif  balance  age  sms  voice    city    phone
# 0    Girev  Andrey         ВИП     2815   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300     3634   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800      410   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500     1981   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800     4969   43   61   8510  Moscow  Samsung

# %%
df['balance_usd'] = (df.balance / 60).round(2).astype(str) + ' $'
df.head()
# Out:
#    surname    name       tarif  balance  age  sms  voice    city    phone  \
# 0    Girev  Andrey         ВИП     2815   29   58   6358  Moscow   Xiaomi
# 1    Bykin    Stas  Все за 300     3634   37   78    602   Kazan  Samsung
# 2   Ivanov    Alex  Всё за 800      410   47   81   3582  Moscow   Huawei
# 3  Andreev  Sergey  Всё за 500     1981   75   98   5442   Kazan    Apple
# 4    Girev    Stas  Всё за 800     4969   43   61   8510  Moscow  Samsung
#
#   balance_usd
# 0     46.92 $
# 1     60.57 $
# 2      6.83 $
# 3     33.02 $
# 4     82.82 $

# %% [markdown]
# **№11**
# Расcчитайте долю смс для каждого пользователя. Для этого определите сколько всего было отправлено СМС, а затем расcчитайте отношение отправленных смс клиента к общему количеству. Столбец назовите sms_volume. Оставьте TOP-3.

# %%
df['sms_volume'] = df.sms / df.sms.sum()

# %%
df.sort_values('sms_volume', ascending=False).head(3)
# Out:
#     surname    name       tarif  balance  age  sms  voice         city  \
# 3   Andreev  Sergey  Всё за 500     1981   75   98   5442        Kazan
# 28   Vlasov  Andrey  Всё за 500     4725   26   93   9441  Vladivostok
# 7     Girev    Alex       Промо     4199   47   90   3925        Kazan
#
#      phone balance_usd  sms_volume
# 3    Apple     33.02 $    0.063844
# 28  Xiaomi     78.75 $    0.060586
# 7    Apple     69.98 $    0.058632

# %% [markdown]
# **№12**
# Cредний возраст клиентов из Казани выше чем во Владивостоке? Функция должна вернуть True - если да и False - если нет.

# %%
df[df.city == 'Kazan'].age.mean() > df[df.city == 'Vladivostok'].age.mean()
# Out:
# True

# %% [markdown]
# **№14**
# Создайте индекс для строк на основе столбцов surname и name. После создания индекса удалите столбцы surname и name

# %%
df = df.set_index(df.surname.str.upper().add('_').add(df.name.str.upper())).drop(['surname', 'name'], axis=1)
df.head()
# Out:
#                      tarif  balance  age  sms  voice    city    phone
# GIREV_ANDREY           ВИП     2815   29   58   6358  Moscow   Xiaomi
# BYKIN_STAS      Все за 300     3634   37   78    602   Kazan  Samsung
# IVANOV_ALEX     Всё за 800      410   47   81   3582  Moscow   Huawei
# ANDREEV_SERGEY  Всё за 500     1981   75   98   5442   Kazan    Apple
# GIREV_STAS      Всё за 800     4969   43   61   8510  Moscow  Samsung

# %%
df.surname.str.upper().add('_').add(df.name.str.upper())
# Out:
# 0        GIREV_ANDREY
# 1          BYKIN_STAS
# 2         IVANOV_ALEX
# 3      ANDREEV_SERGEY
# 4          GIREV_STAS
# 5        BYKIN_ANDREY
# 6         KOZLOV_IGOR
# 7          GIREV_ALEX
# 8      PETROV_NIKOLAY
# 9      ANDREEV_SERGEY
# 10        SMOLOV_STAS
# 11         GIREV_IGOR
# 12      KOZLOV_ANDREY
# 13      IVANOV_SERGEY
# 14      SMOLOV_SERGEY
# 15        KOZLOV_STAS
# 16      VLASOV_ANDREY
# 17        SMOLOV_ALEX
# 18      VLASOV_SERGEY
# 19         BYKIN_ALEX
# 20    ANDREEV_NIKOLAY
# 21         BYKIN_IGOR
# 22       GIREV_SERGEY
# 23       BYKIN_SERGEY
# 24         GIREV_STAS
# 25      SMOLOV_SERGEY
# 26      MEZOV_NIKOLAY
# 27        SMOLOV_STAS
# 28      VLASOV_ANDREY
# 29     IVANOV_NIKOLAY
# dtype: object

# %% [markdown]
# **№15**
# Являются ли лейблы строк уникальными (не повторяющимися)? Верните True - если уникальные и False - если есть дубли.

# %%
df.index.is_unique

# %% [markdown]
# ## 4  Pandas: работа с источниками

# %% [markdown]
# **4.1.6**
# Задание:
# 1) скачайте файл с данными
# 2) определите разделитель и загрузите данные в датафрейм
# 3) определите название станции, на которой было наибольшее количество входов за 4 квартал 2021 года
# В ответе укажите название станции

# %%
ref = 'https://stepik.org/media/attachments/lesson/745992/%D0%9F%D0%B0%D1%81%D1%81%D0%B0%D0%B6%D0%B8%D1%80%D0%BE%D0%BF%D0%BE%D1%82%D0%BE%D0%BA_%D0%9C%D0%BE%D1%81%D0%9C%D0%B5%D1%82%D1%80%D0%BE_2.csv'
df = pd.read_csv(ref, sep=';')
df.sample(1)
# Out:
#      NameOfStation                  Line  Year    Quarter IncomingPassengers  \
# 1270   Охотный ряд  Сокольническая линия  2022  I квартал            3882855
#
#      OutgoingPassengers   global_id NameOfStation_en Line_en Year_en  \
# 1270            3806149  2363398914              NaN     NaN     NaN
#
#      Quarter_en IncomingPassengers_en OutgoingPassengers_en  Unnamed: 13
# 1270        NaN                   NaN                   NaN          NaN

# %%
df2 = df.copy()
df2.drop(0, axis=0, inplace=True)
df2.head()
# Out:
#        NameOfStation                       Line  Year    Quarter  \
# 1             Митино  Арбатско-Покровская линия  2021  I квартал
# 2      Волоколамская  Арбатско-Покровская линия  2021  I квартал
# 3           Строгино  Арбатско-Покровская линия  2021  I квартал
# 4         Крылатское  Арбатско-Покровская линия  2021  I квартал
# 5  Площадь Революции  Арбатско-Покровская линия  2021  I квартал
#
#   IncomingPassengers OutgoingPassengers   global_id NameOfStation_en Line_en  \
# 1            1913498            1829031  1138975996              NaN     NaN
# 2            1236714            1222309  1138975997              NaN     NaN
# 3            1938816            1903731  1138975999              NaN     NaN
# 4            1849616            1818208  1138976000              NaN     NaN
# 5            2324687            2319343  1138976008              NaN     NaN
#
#   Year_en Quarter_en IncomingPassengers_en OutgoingPassengers_en  Unnamed: 13
# ...

# %%
df2.IncomingPassengers.unique()
# Out:
# array(['Входы пассажиров', '1913498', '1236714', ..., '2062912', '543507',
#        '726197'], dtype=object)

# %%
df2.IncomingPassengers.str.replace('Входы пассажиров', '0')
df2.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-2cf871ea4f26> in <module>
# ----> 1 df2.IncomingPassengers.str.replace('Входы пассажиров', np.nan)
#       2 df2.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings\accessor.py in wrapper(self, *args, **kwargs)
#      99                 )
#     100                 raise TypeError(msg)
# --> 101             return func(self, *args, **kwargs)
#     102
#     103         wrapper.__name__ = func_name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings\accessor.py in replace(self, pat, repl, n, case, flags, regex)
#    1309                 warnings.warn(msg, FutureWarning, stacklevel=3)
#    1310             regex = True
# -> 1311         result = self._data.array._str_replace(
#    1312             pat, repl, n=n, case=case, flags=flags, regex=regex
#    1313         )
#
# ...

# %%
df2.IncomingPassengers = df2.IncomingPassengers.astype(int)
df2.sample(10)
# Out:
#            NameOfStation                              Line  Year      Quarter  \
# 744        Нижегородская                Некрасовская линия  2021  III квартал
# 805   Славянский бульвар         Арбатско-Покровская линия  2021   IV квартал
# 881       Площадь Ильича                 Калининская линия  2021   IV квартал
# 1349       Комсомольская                   Кольцевая линия  2022    I квартал
# 842          Новаторская           Большая кольцевая линия  2021   IV квартал
# 739         Авиамоторная                Некрасовская линия  2021  III квартал
# 1357    Ботанический сад     Московское центральное кольцо  2022    I квартал
# 1117           Каховская           Большая кольцевая линия  2022    I квартал
# 1068              Выхино  Таганско-Краснопресненская линия  2021   IV квартал
# 1213           Измайлово     Московское центральное кольцо  2022    I квартал
#
#       IncomingPassengers OutgoingPassengers   global_id NameOfStation_en  \
# ...

# %%
df2[(df2.Year=='2021') & (df2.Quarter=='IV квартал')]\
        .sort_values('IncomingPassengers', ascending=False)\
        .NameOfStation.iloc[0]
# Out:
# 'Комсомольская'

# %% [markdown]
# **4.2.5**
# 1) скачайте файл с данными
# 2) определите разделитель и загрузите данные в датафрейм. Возможно потребуется пропустить какие-то записи для того чтобы загрузка прошла успешно.
# 3) определите сколько всего было входов по всем станциям за всё время (сумма по столбцу IncomingPassengers)

# %%
ref = 'https://stepik.org/media/attachments/lesson/755300/%D0%9F%D0%B0%D1%81%D1%81%D0%B0%D0%B6%D0%B8%D1%80%D0%BE%D0%BF%D0%BE%D1%82%D0%BE%D0%BA_%D0%9C%D0%BE%D1%81%D0%9C%D0%B5%D1%82%D1%80%D0%BE_3.csv'
df = pd.read_csv(ref, sep='|', skiprows=[0, 1, 2, 3, 5, 6])
df.head(10)
# Out:
#        NameOfStation                       Line    Year    Quarter  \
# 0             Митино  Арбатско-Покровская линия  2021.0  I квартал
# 1      Волоколамская  Арбатско-Покровская линия  2021.0  I квартал
# 2           Строгино  Арбатско-Покровская линия  2021.0  I квартал
# 3         Крылатское  Арбатско-Покровская линия  2021.0  I квартал
# 4  Площадь Революции  Арбатско-Покровская линия  2021.0  I квартал
# 5         Бауманская  Арбатско-Покровская линия  2021.0  I квартал
# 6       Первомайская  Арбатско-Покровская линия  2021.0  I квартал
# 7        Беломорская       Замоскворецкая линия  2021.0  I квартал
# 8      Речной вокзал       Замоскворецкая линия  2021.0  I квартал
# 9     Водный стадион       Замоскворецкая линия  2021.0  I квартал
#
#    IncomingPassengers  OutgoingPassengers     global_id  NameOfStation_en  \
# 0           1913498.0           1829031.0  1.138976e+09               NaN
# 1           1236714.0           1222309.0  1.138976e+09               NaN
# ...

# %%
df.IncomingPassengers.sum()
# Out:
# 2514195123.0

# %% [markdown]
# **4.2.6**
# 1) скачайте файл с данными (это новый файл и он отличается от файла с предыдущего степа)
# В столбце IncomingPassengers присутствуют пропущенные значения: 0, NULL, None, не указано
# 2) определите разделитель и загрузите данные в датафрейм. На этапе загрузки сконвертируйте 0, NULL, None, не указано в NaN
# В столбце OutgoingPassengers нули не должны сконвертироваться в NaN!
# 3) С помощью функции pd.isnull определите количество записей, у которых пропущено значение в столбце IncomingPassengers
# В ответе укажите число строк в которых пропущено значение в столбце IncomingPassengers

# %%
ref = 'https://stepik.org/media/attachments/lesson/755300/%D0%9F%D0%B0%D1%81%D1%81%D0%B0%D0%B6%D0%B8%D1%80%D0%BE%D0%BF%D0%BE%D1%82%D0%BE%D0%BA_%D0%9C%D0%BE%D1%81%D0%9C%D0%B5%D1%82%D1%80%D0%BE_4.csv'
df = pd.read_csv(ref, sep='|', skiprows=[1], na_values={'IncomingPassengers': ['0', 'NULL', 'None', 'не указано']})
# , na_values={'IncomingPassengers': ['0', 'NULL', 'None', 'не указано']}
df.head(10)
# Out:
#        NameOfStation                       Line  Year    Quarter  \
# 0             Митино  Арбатско-Покровская линия  2021  I квартал
# 1      Волоколамская  Арбатско-Покровская линия  2021  I квартал
# 2           Строгино  Арбатско-Покровская линия  2021  I квартал
# 3         Крылатское  Арбатско-Покровская линия  2021  I квартал
# 4  Площадь Революции  Арбатско-Покровская линия  2021  I квартал
# 5         Бауманская  Арбатско-Покровская линия  2021  I квартал
# 6       Первомайская  Арбатско-Покровская линия  2021  I квартал
# 7        Беломорская       Замоскворецкая линия  2021  I квартал
# 8      Речной вокзал       Замоскворецкая линия  2021  I квартал
# 9     Водный стадион       Замоскворецкая линия  2021  I квартал
#
#    IncomingPassengers OutgoingPassengers   global_id  NameOfStation_en  \
# 0           1913498.0            1829031  1138975996               NaN
# 1           1236714.0            1222309  1138975997               NaN
# ...

# %%
df[df.IncomingPassengers.isna()].shape[0]
# Out:
# 37

# %%
pd.isnull(df.IncomingPassengers).sum()
# Out:
# 37

# %% [markdown]
# **4.3.2**
# Вы оказались в аналитическом отделе некоторой социальной сети, которая объединяет людей занимающихся благотворительностью. Для вас подготовили выгрузку пользователей в формате csv. Загрузите файл в датафрейм и оставьте только пользователей женского пола. Сохраните датафрейм в формате csv без индекса и в кодировке utf8. Оставьте только две колонки: username и mail Разделитель значений: точка с запятой. Порядок записей не меняйте. Ответ загрузите на степик.

# %%
ref = 'https://stepik.org/media/attachments/lesson/755301/users.csv'
df = pd.read_csv(ref, sep=';')
df.head(10)
# Out:
#                                    job          company          ssn  \
# 0                      Records manager    Duncan-Garcia  241-62-8803
# 1                  Mental health nurse         Rose-Lee  899-12-4937
# 2       Furniture conservator/restorer   Potts and Sons  261-41-9484
# 3                     Ambulance person       Rivera Inc  201-43-6181
# 4           Contracting civil engineer   Hatfield Group  878-83-6667
# 5                         Estate agent  Harrison-Larsen  780-62-6737
# 6  Social research officer, government      Mills-Smith  273-12-9262
# 7           Psychologist, occupational       Welch-Ward  051-51-3449
# 8          Careers information officer      Lopez-Walsh  438-82-5734
# 9                        Administrator     Grant-Santos  532-83-7870
#
#                                            residence  \
# 0           309 Danielle Cliffs\nNorth Amy, NC 69960
# 1                   Unit 5929 Box 0845\nDPO AE 45149
# ...

# %%
df = df[df.sex=='F'][['username', 'mail']]

# %%
df.to_csv('answer_4_3_2.csv', sep=';', index=False, encoding='utf-8')

# %% [markdown]
# **4.3.4**
# Прочитайте первые 50 записей выгрузки и определите количество мужчин.

# %%
ref = 'https://stepik.org/media/attachments/lesson/755301/users.csv'
df = pd.read_csv(ref, sep=';', nrows=50)
df
# Out:
#                                                   job  \
# 0                                     Records manager
# 1                                 Mental health nurse
# 2                      Furniture conservator/restorer
# 3                                    Ambulance person
# 4                          Contracting civil engineer
# 5                                        Estate agent
# 6                 Social research officer, government
# 7                          Psychologist, occupational
# 8                         Careers information officer
# 9                                       Administrator
# 10                Scientist, research (life sciences)
# 11                       Fast food restaurant manager
# 12              Senior tax professional/tax inspector
# 13                               Engineer, structural
# 14                          Public affairs consultant
# 15                               Journalist, magazine
# ...

# %%
df.sex.value_counts()
# Out:
# M    27
# F    23
# Name: sex, dtype: int64

# %%
df.to_csv()

# %% [markdown]
# **4.3.6**
# Скачайте выгрузку и организуйте её чтение чанками. Размер каждого чанка установите в 30 строк. Для пятого чанка с данными определите сколько пользователей с группой крови A+. Группа крови хранится в столбце blood_group

# %%
ref = 'https://stepik.org/media/attachments/lesson/755301/users.csv'
reader = pd.read_csv(ref, sep=';', chunksize=30)

# %%
counter = 0
for df in reader:
    counter += 1
    if counter == 5:
        print((df.blood_group == 'A+').sum())
# Out:
# 4

# %%
gen = (i**2 for i in range(10))
for i, val in enumerate(gen):
    if i==5:
        print(val)
print(len(list(gen)))
# Out:
# 25
# 0

# %% [markdown]
# **4.4.1**
# Скачайте набор данных в формате JSON. Набор данных позволяет получить информацию о видах билетов и тарифах на проезд в метрополитене и монорельсе, наземном пассажирском транспорте и пригородном железнодорожном транспорте города Москвы.
# Скачайте файл JSON. Загрузите данные в датафрейм и определите самый дешевый тариф. Стоимость указана в столбце TicketCost, а наименование тарифа NameOfTariff
# В поле ответа вставьте значение из столбца NameOfTariff

# %%
import requests
url = 'https://stepik.org/media/attachments/lesson/755302/data-399-2022-07-01.json'
r = requests.get(url)
data = r.json()

# %%
data[:2]
# Out:
# [{'ID': 200,
#   'NameOfTariff': '������� �� ����� 2 �������',
#   'TicketZone': [{'TicketZone': '���� �'},
#    {'TicketZone': '���� �'},
#    {'TicketZone': '����� ������ � � �'},
#    {'TicketZone': '���'}],
#   'global_id': 19368709,
#   'NumberOfZone': '-',
#   'TariffDistance': '-',
#   'TypeOfTransport': '������������, ���������, �������, ����������, �������, ���',
#   'NameOfCarrier': [{'NameOfCarrier': '��� ����������� �������������'},
#    {'NameOfCarrier': '��� ������������'},
#    {'NameOfCarrier': '����������� ��������� ����������, ���������� �� ��������������� ����������'}],
#   'TicketCost': 114,
#   'TicketValidity': '5 ����, ������� ���� �������'},
#  {'ID': 700,
#   'NameOfTariff': '������� �� ����� 60 �������',
#   'TicketZone': [{'TicketZone': '���� �'},
#    {'TicketZone': '���� �'},
#    {'TicketZone': '����� ������ � � �'}],
#   'global_id': 19368716,
#   'NumberOfZone': '-',
#   'TariffDistance': '-',
# ...

# %%
# решил проще пойти
url = 'https://stepik.org/media/attachments/lesson/755302/data-399-2022-07-01.json'
df = pd.read_json(url, encoding='windows-1251', )

# %%
df.sort_values('TicketCost')
# Out:
#       ID                                       NameOfTariff  \
# 17  7300                                 «Разовый» льготный
# 16  7200                          «Разовый билет» за 1 зону
# 13  5200                                    «Кошелек» - ТАТ
# 15  5400  Банковская карта с транспортным приложением, 1...
# 14  5300  Банковская карта с транспортным приложением 1 ...
# 12  5100                  «Кошелек» метро/монорельс/МЦК/МЦД
# 34  8900  Билет для поездок в пределах перечня железнодо...
# 28  8300  Банковская карта с технологией бесконтактной о...
# 23  7400                  «Кошелек» метро/монорельс/МЦК/МЦД
# 27  8200  Банковская карта с технологией бесконтактной о...
# 33  8800  Банковская карта с технологией бесконтактной о...
# 30  8500  Аутентификация на основании изображения на уст...
# 19   100  «Единый» не более 1 поездки с возможностью реа...
# 11  4900                     Провоз не более 1 места багажа
# 18  5000                             «Кошелек» - «90 минут»
# ...

# %% [markdown]
# **4.4.5**
# Возвращаемся к выгрузке про пользователей из социальной сети. Снова загрузите ее в датафрейм, оставьте только столбцы username, name, sex и сохраните в формате json (кодировка utf8). Сохранение выполните таким образом чтобы ключами были названия колонок, а значениями вложенные словари, которые будут хранить лейбл строки и само значение.
# Когда функция to_json сохранит файл - загружайте на степик. Дополнительно форматировать результат для лучшей читаемости не следует. Чтобы тестовая система приняла результат - в файле .json должна быть всего одна строка.

# %%
url = 'https://stepik.org/media/attachments/lesson/755302/users.csv'
df = pd.read_csv(url, sep=';')
df.head()
# Out:
#                               job         company          ssn  \
# 0                 Records manager   Duncan-Garcia  241-62-8803
# 1             Mental health nurse        Rose-Lee  899-12-4937
# 2  Furniture conservator/restorer  Potts and Sons  261-41-9484
# 3                Ambulance person      Rivera Inc  201-43-6181
# 4      Contracting civil engineer  Hatfield Group  878-83-6667
#
#                                            residence  \
# 0           309 Danielle Cliffs\nNorth Amy, NC 69960
# 1                   Unit 5929 Box 0845\nDPO AE 45149
# 2  130 Vargas Trail Apt. 244\nNorth Rebecca, WV 1...
# 3             7173 Adrian Shoal\nWest Paul, NJ 24509
# 4  558 Andrea Prairie Apt. 869\nGeraldside, TX 73555
#
#                                  current_location blood_group  \
# 0  (Decimal('-79.694044'), Decimal('145.837904'))         AB+
# 1  (Decimal('16.6696785'), Decimal('-38.243842'))          A-
# 2  (Decimal('-27.9623815'), Decimal('75.091620'))          B-
# ...

# %%
df2 = df[['username', 'name', 'sex']]
df2.head()
# Out:
#        username              name sex
# 0   lambertemma        Stacy Reed   F
# 1         greid      Carol Farley   F
# 2  scottmercado  Russell Whitaker   M
# 3     kristin75    Maureen Powers   F
# 4       lhansen   Edward Mcdonald   M

# %%
df2.to_json('answer_4_5_5.json', orient='columns')

# %% [markdown]
# **4.5.2**
# Ваш друг Илья работает аналитиком в компании, которая занимается установкой и обслуживанием платных стоянок (стоек) для парковки велосипедов. Сегодня на работе ему поручили посчитать вместимость всех велосипедных стоянок в районе Тропарёво-Никулино. Говорит, что компания планирует устанавливать новые платные стоянки для велосипедов в этом районе. Проблема заключается в том, что данные лежат в формате HDF5 и Илья никогда раньше не работал с ним. Он попросил вашей помощи и сказал, что район записан в столбце District, а вместительность парковки в столбце Capacity
# Посчитайте суммарную вместительность велосипедных парковок в районе Тропарёво-Никулино.

# %%
df = pd.read_hdf('data_store2.h5', key='parking_table', mode='a')
# не сработало: версия юпитера или питона старая

# %%
df[df.District=='район Тропарёво-Никулино'].Capacity.sum()
# Out:
# 26

# %%
df = pd.read_json('data-403-2022-10-12.json', encoding='windows-1251')
## а эти данные не соответствуют данным в hdf файле :(

# %%
df[df.District=='район Тропарёво-Никулино'].Capacity.sum()
# Out:
# 32

# %% [markdown]
# **4.5.4**
# Загрузите данные в датафрейм и определите суммарный общий прирост постоянного населения за период с 2014 по 2020 (включительно) для субъекта Камчатский край
# Т.е. мы ходим понять, что произошло с приростом за этот период: был ли он положительным или отрицательным и в каком количестве.

# %%
url = 'https://stepik.org/media/attachments/lesson/755303/23110000100100200001_%D0%9E%D0%B1%D1%89%D0%B8%D0%B9_%D0%BF%D1%80%D0%B8%D1%80%D0%BE%D1%81%D1%82_%D0%BF%D0%BE%D1%81%D1%82%D0%BE%D1%8F%D0%BD%D0%BD%D0%BE%D0%B3%D0%BE_%D0%BD%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D1%8F.html'
df = pd.read_html(url)[0]

# %%
df
# Out:
#                         Unnamed: 0    Unnamed: 1  \
# 0                              NaN           NaN
# 1                              NaN           NaN
# 2                    все население  w2:p_mest:11
# 3             Российская Федерация           643
# 4    Центральный федеральный округ           030
# ..                             ...           ...
# 98             Магаданская область   44000000000
# 99             Сахалинская область   64000000000
# 100   Еврейская автономная область   99000000000
# 101     Чукотский автономный округ   77000000000
# 102     Крымский федеральный округ           039
#
#     23110000100100200001 Общий прирост постоянного населения  \
# 0                                            За период
# 1                                       январь 2022 г.
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...

# %%
df[df['Unnamed: 0'] == 'Камчатский край'].iloc[:, 3:10].astype('int').sum(axis=1)
# Out:
# 94   -8197
# dtype: int64

# %%
df[df['Unnamed: 0'] == 'Камчатский край']
# Out:
#          Unnamed: 0   Unnamed: 1  \
# 94  Камчатский край  30000000000
#
#    23110000100100200001 Общий прирост постоянного населения  \
# 94                                                NaN
#
#    23110000100100200001 Общий прирост постоянного населения.1  \
# 94                                              -2595
#
#    23110000100100200001 Общий прирост постоянного населения.2  \
# 94                                              -1153
#
#    23110000100100200001 Общий прирост постоянного населения.3  \
# 94                                              -1387
#
#    23110000100100200001 Общий прирост постоянного населения.4  \
# 94                                                828
#
#    23110000100100200001 Общий прирост постоянного населения.5  \
# 94                                               -834
#
#    23110000100100200001 Общий прирост постоянного населения.6  \
# 94                                              -1707
#
# ...

# %% [markdown]
# **4.5.6**
# Загрузите данные в датафрейм и определите в какой из областей произошел наибольший отрицательный прирост постоянного населения за 2020 год (сравниваем абсолютные значения)

# %%
url = 'https://stepik.org/media/attachments/lesson/755303/23110000100100200001_%D0%9E%D0%B1%D1%89%D0%B8%D0%B9_%D0%BF%D1%80%D0%B8%D1%80%D0%BE%D1%81%D1%82_%D0%BF%D0%BE%D1%81%D1%82%D0%BE%D1%8F%D0%BD%D0%BD%D0%BE%D0%B3%D0%BE_%D0%BD%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D1%8F.html'
df = pd.read_html(url, header=2)[0]

# %%
df.set_index('Unnamed: 0', inplace=True)
df
# Out:
#                                  Unnamed: 1  январь 2022 г.   2014 г.  \
# Unnamed: 0
# все население                  w2:p_mest:11             NaN       NaN
# Российская Федерация                    643             NaN  305469.0
# Центральный федеральный округ           030             NaN  131605.0
# Белгородская область            14000000000             NaN    3828.0
# Брянская область                15000000000             NaN   -9659.0
# ...                                     ...             ...       ...
# Магаданская область             44000000000             NaN   -2241.0
# Сахалинская область             64000000000             NaN   -2636.0
# Еврейская автономная область    99000000000             NaN   -2009.0
# Чукотский автономный округ      77000000000             NaN     -15.0
# Крымский федеральный округ              039             NaN       0.0
#
#                                 2015 г.   2016 г.   2017 г.  2018 г.  2019 г.  \
# Unnamed: 0
# ...

# %%
lst = [
    'Кировская область', 
    'Магаданская область', 
    'Сахалинская область', 
    'Калужская область', 
    'Ярославская область', 
    'Свердловская область', 
]
df[df['2020 г.'] < 0]['2020 г.'][lst].sort_values()
# Out:
# Unnamed: 0
# Свердловская область   -20614.0
# Кировская область      -12229.0
# Ярославская область    -11965.0
# Сахалинская область     -2636.0
# Калужская область       -1595.0
# Магаданская область     -1115.0
# Name: 2020 г., dtype: float64

# %% [markdown]
# **4.5.7**
# Вы продолжаете работу в аналитическом отделе некоторой социальной сети, которая объединяет людей занимающихся благотворительностью. Коллеги аналитики для вас подготовили выгрузку пользователей в формате XML. Загрузите файл XML в датафрейм и посчитайте сколько пользователей женского пола с группой крови B+ в выгрузке.

# %%
from lxml import objectify
# import requests

# %%
# xml = requests.get('https://stepik.org/media/attachments/lesson/755303/users.xml').text # не одолел
parsed = objectify.parse('users.xml')
root = parsed.getroot()

data = []
for el in root.element:
    row_dict = {}
    for e in el.getchildren():
        row_dict[e.tag] = e.text  # e.pyval
    # print(row_dict)
    data.append(row_dict)
    # print('---------')
df = pd.DataFrame(data)
df.head()
# Out:
#                                             address       birthdate  \
# 0         29948 Mason Summit\nRoblesshire, VA 63080   -620352000000
# 1  65586 Beverly Camp Apt. 519\nToddshire, NY 32950    813456000000
# 2                  Unit 5719 Box 7188\nDPO AA 69227  -1544140800000
# 3        4201 Sydney Brooks\nPort Raymond, ND 10924  -1363219200000
# 4       97225 Matthew Branch\nNew Caitlyn, IN 59591  -1033603200000
#
#   blood_group                     company current_location  \
# 0          B-              Mills-Mitchell             None
# 1          B+  Hampton, Torres and Parker             None
# 2          B+  Hicks, Lewis and Hernandez             None
# 3         AB+                 Morse-Mccoy             None
# 4          A+                  Martin Inc             None
#
#                                    job                   mail  \
# 0       Investment banker, operational  joymcdonald@gmail.com
# 1                            Press sub   ayalaaaron@gmail.com
# ...

# %%
df.query("blood_group == 'B+' & sex == 'F'")
# Out:
#                                               address       birthdate  \
# 1    65586 Beverly Camp Apt. 519\nToddshire, NY 32950    813456000000
# 22  1039 Steven Junction\nLake Micheleburgh, UT 23835   1327795200000
# 24             0871 Lucas Branch\nBurketown, VT 42645  -1497916800000
# 30  04865 Carter Fall Suite 326\nEast Stephenshire...    134265600000
# 44  13330 Vincent Glen Suite 273\nEast Mariahborou...    634780800000
#
#    blood_group                      company current_location  \
# 1           B+   Hampton, Torres and Parker             None
# 22          B+               Jacobson-Huynh             None
# 24          B+   Roberts, Hull and Sullivan             None
# 30          B+  Harris, Williams and Bailey             None
# 44          B+     Williams, Reed and Estes             None
#
#                                      job                   mail  \
# 1                              Press sub   ayalaaaron@gmail.com
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect('chinook_sqlite_db/chinook.db')

# %%
cursor = conn.cursor()

# %%
cursor.execute("SELECT * FROM invoices;")

# %%
cursor.description
# Out:
# (('InvoiceId', None, None, None, None, None, None),
#  ('CustomerId', None, None, None, None, None, None),
#  ('InvoiceDate', None, None, None, None, None, None),
#  ('BillingAddress', None, None, None, None, None, None),
#  ('BillingCity', None, None, None, None, None, None),
#  ('BillingState', None, None, None, None, None, None),
#  ('BillingCountry', None, None, None, None, None, None),
#  ('BillingPostalCode', None, None, None, None, None, None),
#  ('Total', None, None, None, None, None, None))

# %%
raw = cursor.fetchall()

# %%
df = pd.DataFrame(raw, columns=[i[0] for i in cursor.description])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412 entries, 0 to 411
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   InvoiceId          412 non-null    int64
#  1   CustomerId         412 non-null    int64
#  2   InvoiceDate        412 non-null    object
#  3   BillingAddress     412 non-null    object
#  4   BillingCity        412 non-null    object
#  5   BillingState       210 non-null    object
#  6   BillingCountry     412 non-null    object
#  7   BillingPostalCode  384 non-null    object
#  8   Total              412 non-null    float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 29.1+ KB

# %%
df.sample(10)
# Out:
#      InvoiceId  CustomerId          InvoiceDate         BillingAddress  \
# 391        392           4  2013-10-03 00:00:00       Ullevålsveien 14
# 204        205          44  2011-06-20 00:00:00        Porthaninkatu 9
# 247        248          40  2011-12-24 00:00:00         8, Rue Hanovre
# 231        232          17  2011-10-21 00:00:00        1 Microsoft Way
# 364        365          31  2013-06-01 00:00:00  194A Chain Lake Drive
# 283        284          59  2012-05-30 00:00:00      3,Raj Bhavan Road
# 119        120          58  2010-06-12 00:00:00    12,Community Centre
# 235        236          38  2011-10-31 00:00:00    Barbarossastraße 19
# 29          30          38  2009-05-06 00:00:00    Barbarossastraße 19
# 268        269          36  2012-03-26 00:00:00     Tauentzienstraße 8
#
#     BillingCity BillingState BillingCountry BillingPostalCode  Total
# 391        Oslo         None         Norway              0171   1.98
# ...

# %%
import sqlalchemy as sql

# %%
engine = sql.create_engine("sqlite:///./chinook_sqlite_db/chinook.db")

# %%
df = pd.read_sql("SELECT * FROM invoices;", engine)
df.head()
# Out:
#    InvoiceId  CustomerId          InvoiceDate           BillingAddress  \
# 0          1           2  2009-01-01 00:00:00  Theodor-Heuss-Straße 34
# 1          2           4  2009-01-02 00:00:00         Ullevålsveien 14
# 2          3           8  2009-01-03 00:00:00          Grétrystraat 63
# 3          4          14  2009-01-06 00:00:00           8210 111 ST NW
# 4          5          23  2009-01-11 00:00:00          69 Salem Street
#
#   BillingCity BillingState BillingCountry BillingPostalCode  Total
# 0   Stuttgart         None        Germany             70174   1.98
# 1        Oslo         None         Norway              0171   3.96
# 2    Brussels         None        Belgium              1000   5.94
# 3    Edmonton           AB         Canada           T6G 2C7   8.91
# 4      Boston           MA            USA              2113  13.86

# %%
df = pd.DataFrame(np.arange(1, 10).reshape(3, 3), columns=list('ABC'))
df.at[1, 'A'] = '123'
type(df.at[1, 'A'])
# Out:
# numpy.int32

# %% [markdown]
# **4.6.2**
# В базе данных sqlite3 создана таблица stations, которая содержит информацию о местоположении станций велопроката, количестве мест на станции и слотов для парковки велосипедов.
# Выполните действия:
# 1) Выгрузите имя станции (столбец Name),  количество мест на станции (столбец StationCapacity), адресный ориентир (столбец Location).
# 2) Выполните сортировку датафрейма по правилам:
# сначала идут станции с наибольшим количеством мест
# если у нескольких станций одинаковое количество мест, то отсортируйте их в алфавитном порядке
# 3) Сохраните датафрейм в формате csv: без индекса, разделитель точка с запятой, кодировка utf8

# %%
import sqlite3
conn = sqlite3.connect('local_db.db')

# %%
df = pd.read_sql("SELECT Name, StationCapacity, Location FROM stations;", conn)

# %%
df.StationCapacity = df.StationCapacity.astype(int)

# %%
df.sort_values(['StationCapacity', 'Name'], ascending=[False, True], inplace=True)

# %%
df.to_csv('answer_4_6_2.csv', index=False, sep=';', encoding='utf-8')

# %% [markdown]
# **4.6.5**
# Ваш старый друг Андрей купил электрокар Tesla Model X, а теперь подумывает о покупке квартиры в другом районе Москвы. Андрей устал, что в его районе почти всегда заняты зарядные станции и подзарядка машины превратилась в проблему, поэтому ему важно, чтобы на районе было много зарядных станций.
# Порекомендуйте Андрею ТОП-3 района по количеству зарядных станций. Андрей уже подготовил для вас выгрузку в Excel - данные на двух листах.

# %%
df1 = pd.read_excel('Зарядные_станции_для_электромобилей.xlsx', sheet_name=0, header=1)

# %%
df1
# Out:
#        Код                                   Наименование  \
# 0    25586       ЭЗС Колпачный переулок дом 3, строение 2
# 1    25588                   ЭЗС улица Макаренко дом 1/19
# 2    25593                ЭЗС Потаповский переулок дом 14
# 3    28237             ЭЗС 1-й Кожуховский проезд дом 1/7
# 4    28239        ЭЗС Докучаев переулок дом 3, строение 1
# ..     ...                                            ...
# 100  29770              ЭЗС Озерковская набережная дом 44
# 101  29935              ЭЗС Старомонетный переулок дом 11
# 102  32031  ЭЗС улица Большие Каменщики дом 6, строение 1
# 103  32036            ЭЗС площадь Киевского Вокзала дом 2
# 104  32041                       ЭЗС улица Грекова дом 3Ж
#
#                       Административный округ                      Район  \
# 0         Центральный административный округ            Басманный район
# 1         Центральный административный округ            Басманный район
# ...

# %%
df2 = pd.read_excel('Зарядные_станции_для_электромобилей.xlsx', sheet_name=1, header=10)

# %%
df2
# Out:
#       Код                                       Наименование  \
# 0   32044          ЭЗС Новороссийская улица дом 24, корпус 1
# 1   32046            ЭЗС Рязанский проспект дом 30, корпус 2
# 2   32050                 ЭЗС 1-й Автозаводский проезд дом 5
# 3   32053              ЭЗС улица Усиевича дом 29, строение 2
# 4   32069                  ЭЗС улица Новинки дом 27 корпус 1
# 5   32072         ЭЗС Волгоградский проспект дом 32 корпус 2
# 6   32077             ЭЗС Последний переулок дом 6, корпус 1
# 7   32080                         ЭЗС улица Верземнека дом 6
# 8   32085                ЭЗС Лесная улица дом 61, строение 1
# 9   32091   ЭЗС Большой Дровяной переулок дом 17, строение 1
# 10  33194               ЭЗС Малый Демидовский переулок дом 6
# 11  33207                          ЭЗС Москва площадь Европы
# 12  33208                          ЭЗС Москва площадь Европы
# 13  33210        ЭЗС улица Пресненский Вал дом 7, строение 1
# ...

# %%
df = pd.concat([df1, df2])

# %%
df = df.reset_index(drop=True).iloc[:, : 8]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Код                     159 non-null    int64
#  1   Наименование            159 non-null    object
#  2   Административный округ  159 non-null    object
#  3   Район                   159 non-null    object
#  4   Адрес                   159 non-null    object
#  5   Долгота в WGS-84        159 non-null    float64
#  6   Широта в WGS-84         159 non-null    float64
#  7   global_id               159 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 10.1+ KB

# %%
df.groupby('Район').count().global_id.sort_values(ascending=False)
# Out:
# Район
# Пресненский район             11
# Мещанский район               10
# Басманный район                9
# район Хамовники                8
# Тверской район                 7
#                               ..
# район Бибирево                 1
# Бабушкинский район             1
# район Выхино-Жулебино          1
# район Крылатское               1
# район Проспект Вернадского     1
# Name: global_id, Length: 64, dtype: int64
