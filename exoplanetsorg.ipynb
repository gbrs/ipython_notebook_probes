# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('G://exoplanetsorg210111-2.csv', header=0)
df
# Out:
#                name  m_sin_i__jupiter  axis_semi_major__au  \
# 0      Kepler-107 d               NaN             0.078010
# 1     Kepler-1049 b               NaN             0.034472
# 2      Kepler-813 b               NaN             0.137610
# 3      Kepler-427 b          0.310432             0.091351
# 4     Kepler-1056 b               NaN             0.185149
# ...             ...               ...                  ...
# 5742    KOI 7978.01               NaN             0.082100
# 5743    KOI 7982.01               NaN             1.028700
# 5744    KOI 8193.01               NaN             0.995500
# 5745    KOI 7986.01               NaN             0.029000
# 5746    KOI 7988.01               NaN             1.223300
#
#       period_orbital__day  eccenricity_orbital  w__deg  periastron_time__jd  \
# 0                7.958203                  NaN    90.0         2.454971e+06
# 1                3.273461                  0.0    90.0                  NaN
# ...

# %%
df.describe()
# Out:
#        m_sin_i__jupiter  axis_semi_major__au  period_orbital__day  \
# count        970.000000          5627.000000          5733.000000
# mean           2.059481             0.383545           254.594620
# std            3.013581             2.068768          5194.153163
# min            0.000000             0.000000             0.179715
# 25%            0.346817             0.056500             5.118000
# 50%            1.041380             0.108427            13.839890
# 75%            2.292277             0.283746            57.388826
# max           22.626100           113.443000        318498.000000
#
#        eccenricity_orbital       w__deg  periastron_time__jd  \
# count          4784.000000  3033.000000         1.697000e+03
# mean              0.030990   108.003508         2.454726e+06
# std               0.104104    63.761567         2.951856e+03
# min               0.000000  -159.800000         2.439969e+06
# 25%               0.000000    90.000000         2.454596e+06
# ...

# %%
df.query('m_sin_i__jupiter == 0')
# Out:
#               name  m_sin_i__jupiter  axis_semi_major__au  \
# 649       K2-141 c               0.0             0.068301
# 759   Kepler-407 b               0.0             0.014975
# 1190      K2-105 b               0.0             0.080280
# 1259     WASP-33 b               0.0             0.025548
# 2280  Kepler-100 c               0.0             0.109963
# 3158    CoRoT-24 b               0.0             0.056289
# 3262  Kepler-102 b               0.0             0.055137
#
#       period_orbital__day  eccenricity_orbital  w__deg  periastron_time__jd  \
# 649              7.748500                  0.0    90.0         2.457751e+06
# 759              0.669311                  0.0    90.0         2.454967e+06
# 1190             8.266902                  NaN     NaN                  NaN
# 1259             1.219870                  0.0    90.0         2.454590e+06
# 2280            12.815900                  0.0     NaN                  NaN
# ...

# %%
df.query('velocity_semiaplitude__ms == 0')
# Получилось семь планет с нулевой массой. Это ладно. Но нулевая лучевая скорость это как?
# Out:
#               name  m_sin_i__jupiter  axis_semi_major__au  \
# 649       K2-141 c               0.0             0.068301
# 759   Kepler-407 b               0.0             0.014975
# 1190      K2-105 b               0.0             0.080280
# 1259     WASP-33 b               0.0             0.025548
# 2280  Kepler-100 c               0.0             0.109963
# 3158    CoRoT-24 b               0.0             0.056289
# 3262  Kepler-102 b               0.0             0.055137
#
#       period_orbital__day  eccenricity_orbital  w__deg  periastron_time__jd  \
# 649              7.748500                  0.0    90.0         2.457751e+06
# 759              0.669311                  0.0    90.0         2.454967e+06
# 1190             8.266902                  NaN     NaN                  NaN
# 1259             1.219870                  0.0    90.0         2.454590e+06
# 2280            12.815900                  0.0     NaN                  NaN
# ...
